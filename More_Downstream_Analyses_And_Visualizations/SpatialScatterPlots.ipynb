# %% [markdown]
# #### This particular notebook includes a FFPE block age QC comparison within Dataset 1 Xenium.
#
# #### Required input files:
#
# * Filtered transcript file (for each dataset/rep/slide)
# * Annotated cell-based data object (for each dataset)
#
# Note: r denotes filtered transcript file (filtering removal)
#
# Environment: Please create and activate the conda environment provided in default_env.yaml before running this notebook

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import scanpy as sc
import squidpy as sq

import gzip
import anndata

import os

import matplotlib.colors as mcolors

from scipy.stats import kruskal
from scipy.stats import mannwhitneyu
from itertools import combinations
from statsmodels.stats.multitest import multipletests

# %% [markdown]
# ## Load in data
#
# Note:
# * Parts 1, 2, and 3 of this notebook are set up to use Xenium Dataset 1 slide 1.
# * Part 4 of this notebook is set to use Xenium Dataset 1 Integrated (slides 1 and 2).

# %%
# Xenium Dataset 1 slide 1 transcript file
Xenium_transcripts_r = pd.read_csv('/path/Xenium_transcripts_r.csv')

# Xenium Dataset 1 Integrated (slides 1 and 2) annotated data object
Int_XeniumData = sc.read_h5ad('/path/25_11_22_Xenium_Dataset1_290_IntReps1and2_Annotated.h5ad')

# %%
### Subset Xenium Dataset 1 Integrated data object to only include slide 1 (Sept)

# Subset to only keep rows where batch == 'Sept' (rep1)
XeniumData = Int_XeniumData[Int_XeniumData.obs['batch'] == 'Sept'].copy()

# Reset index to remove AnnData index
XeniumData.obs.reset_index(inplace=True)

# Rename the new column to cell_id
XeniumData.obs.rename(columns={"index": "cell_id"}, inplace=True)

# Display results
display(XeniumData)
display(XeniumData.obs)

# %% [markdown]
# # Part 1: Plotting Genes of Interest
#
# Currently set up to use Xenium Dataset 1 slide 1

# %% [markdown]
# ## DESeq Genes of Interest

# %% [markdown]
# #### Format data accordingly

# %%
# Merge to add core info
Xenium_transcripts_merged = pd.merge(Xenium_transcripts_r, XeniumData.obs[['cell_id', 'Patient_ID_cores_combined']], on='cell_id', how='inner')

# View
Xenium_transcripts_merged

# %% [markdown]
# #### Plot based on fov

# %%
def plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, gene_populations, condition, fov, colors, fig_width=5, fig_height=6, save_plot=False):
    # Define the path where the plot will be saved
    save_path = '/path/DESeqGenesOfInterestPlots/Fovs/'
    
    # Ensure that directory exists if saving the plot
    if save_plot:
        os.makedirs(save_path, exist_ok=True)
    
    # Filter genes by fov
    specified_fov = Xenium_transcripts_merged[Xenium_transcripts_merged['fov_name'] == fov]
    
    # Extract subset of data for specified gene populations
    gene_subset = specified_fov[specified_fov['feature_name'].isin(gene_populations)]
    
    # Combine data from all genes
    combined_data = []
    for i, gene in enumerate(gene_populations):
        gene_data = gene_subset[gene_subset['feature_name'] == gene]
        gene_data = gene_data.assign(color=colors[i])
        combined_data.append(gene_data)
        
    combined_data =pd.concat(combined_data)
    
    # Shuffle the combined data
    combined_data = combined_data.sample(frac=1, random_state=42).reset_index(drop=True)
    
    # Create a figure
    fig, ax = plt.subplots(figsize=(fig_width, fig_height))
 
    # Plot
    ax.scatter(
        combined_data['x_location'],
        combined_data['y_location'],
        s=40,  # Adjust the size of the scatter plot dots
        alpha=0.5,  # Adjust alpha for better visualization
        c=combined_data['color'],
        label=combined_data['feature_name']
    )
    
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel('spatial1')
    ax.set_ylabel('spatial2')
    ax.set_aspect('equal')
    
    # Add legend at the top right
    legend_elements = [plt.Line2D([0], [0], marker='o', color=colors[i], markersize=5, label=gene, linestyle='None')
                       for i, gene in enumerate(gene_populations)]
    legend = ax.legend(handles=legend_elements, loc='upper center', bbox_to_anchor=(0.5, -0.05), fontsize=10)
    
    plt.tight_layout()  # Adjust layout to make room for the legend
    
    # Save plot to file if save_plot is True
    if save_plot:
        gene_population_str = "_".join(gene_populations)
        file_name = f"SpatialScatterPlot_Xenium_{condition}_fov{fov}_genes{gene_population_str}.pdf"
        full_path = os.path.join(save_path, file_name)
        plt.savefig(full_path, format='pdf')
    
    plt.show()

# %%
plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, 
                                  gene_populations = ['AQP8', 'EPCAM', 'PIGR'], 
                                  condition = "HC",
                                  fov = "S2", # HC
                                  colors = ['deeppink', 'darkorange', 'royalblue'],
                                  save_plot = False)

# %%
plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, 
                                  gene_populations = ['BANK1', 'IGHD', 'MSA41', 'SELL'], 
                                  condition = "HC", 
                                  fov = "S2", # HC,
                                  colors = ['deeppink', 'darkorange', 'royalblue', 'mediumseagreen'],
                                  save_plot = False)

# %%
plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, 
                                  gene_populations = ['S100A8', 'S100A9', 'TIMP1'], 
                                  condition = "HC", 
                                  fov = "S2", # HC
                                  colors = ['deeppink', 'darkorange', 'royalblue'],
                                  save_plot = False)

# %%
plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, 
                                  gene_populations = ['AQP8', 'EPCAM', 'PIGR'], 
                                  condition = "PREVDZ_R", 
                                  fov = "AB13", # PREVDZ_R
                                  colors = ['deeppink', 'darkorange', 'royalblue'],
                                  save_plot = False)

# %%
plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, 
                                  gene_populations = ['BANK1', 'IGHD', 'MSA41', 'SELL'], 
                                  condition = "PREVDZ_R",  
                                  fov = "AB13", # PREVDZ_R
                                  colors = ['deeppink', 'darkorange', 'royalblue', 'mediumseagreen'],
                                  save_plot = False)

# %%
plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, 
                                  gene_populations = ['S100A8', 'S100A9', 'TIMP1'], 
                                  condition = "PREVDZ_R",  
                                  fov = "AB13", # PREVDZ_R
                                  colors = ['deeppink', 'darkorange', 'royalblue'],
                                  save_plot = False)

# %%
plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, 
                                  gene_populations = ['CD1C', 'MMP1', 'MMP3'], 
                                  condition = "PREVDZ_R",  
                                  fov = "AB13", # PREVDZ_R
                                  colors = ['deeppink', 'darkorange', 'royalblue'],
                                  save_plot = False)

# %%
plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, 
                                  gene_populations = ['BANK1', 'CD19', 'MS4A1', 'SELL'], 
                                  condition = "PREVDZ_R",  
                                  fov = "AB13", # PREVDZ_R
                                  colors = ['deeppink', 'darkorange', 'royalblue', 'mediumseagreen'],
                                  save_plot = False)

# %%
plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, 
                                  gene_populations = ['AGR2', 'PIGR', 'SPINK4'], 
                                  condition = "PREVDZ_R",  
                                  fov = "AB13", # PREVDZ_R
                                  colors = ['deeppink', 'darkorange', 'royalblue'],
                                  save_plot = False)

# %%
plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, 
                                  gene_populations = ['AQP8', 'EPCAM', 'PIGR'], 
                                  condition = "PREVDZ_NR",  
                                  fov = "Q12", # PREVDZ_NR
                                  colors = ['deeppink', 'darkorange', 'royalblue'],
                                  save_plot = False)

# %%
plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, 
                                  gene_populations = ['BANK1', 'IGHD', 'MSA41', 'SELL'], 
                                  condition = "PREVDZ_NR",  
                                  fov = "Q12", # PREVDZ_NR
                                  colors = ['deeppink', 'darkorange', 'royalblue', 'mediumseagreen'],
                                  save_plot = False)

# %%
plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, 
                                  gene_populations = ['S100A8', 'S100A9', 'TIMP1'], 
                                  condition = "PREVDZ_NR",  
                                  fov = "Q12", # PREVDZ_NR
                                  colors = ['deeppink', 'darkorange', 'royalblue'],
                                  save_plot = False)

# %%
plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, 
                                  gene_populations = ['CD1C', 'MMP1', 'MMP3'], 
                                  condition = "PREVDZ_NR",  
                                  fov = "Q12", # PREVDZ_NR
                                  colors = ['deeppink', 'darkorange', 'royalblue'],
                                  save_plot = False)

# %%
plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, 
                                  gene_populations = ['BANK1', 'CD19', 'MS4A1', 'SELL'], 
                                  condition = "PREVDZ_NR",  
                                  fov = "Q12", # PREVDZ_NR
                                  colors = ['deeppink', 'darkorange', 'royalblue', 'mediumseagreen'],
                                  save_plot = False)

# %%
plot_spatial_scatter_with_overlay_Xenium_fov(Xenium_transcripts_merged, 
                                  gene_populations = ['AGR2', 'PIGR', 'SPINK4'], 
                                  condition = "PREVDZ_NR",  
                                  fov = "Q12", # PREVDZ_NR
                                  colors = ['deeppink', 'darkorange', 'royalblue'],
                                  save_plot = False)

# %% [markdown]
# # Part 2: Plotting Fine Annotation Clusters of Interest
#
# Currently set up to use Xenium Dataset 1 slide 1

# %%
sc.pl.umap(
    XeniumData,
    color=[
        "24_05_29_Fine_annotations_Xenium_combined",
    ],
    wspace=0.4,
)

# %% [markdown]
# ## IEC_CT_colonocyte, MNP_monocyte, and Fibroblast_IAF clusters

# %%
def plot_spatial_scatter_with_overlay(
    XeniumData,
    cell_populations,
    core_id,
    save_path=None,
    fig_width=5,
    fig_height=6
):
    annotation_key = '24_05_29_Fine_annotations_Xenium_combined'
    core_key = 'Patient_ID_cores_combined'

    # 1. Subset by core
    core_mask = XeniumData.obs[core_key] == core_id
    specified_core = XeniumData[core_mask, :].copy()

    # 2. Subset by cell populations (use .values to avoid AnnData index weirdness)
    pop_mask = specified_core.obs[annotation_key].isin(cell_populations).values
    cell_subset = specified_core[pop_mask, :].copy()

    # 3. Set up figure
    fig, ax = plt.subplots(figsize=(fig_width, fig_height))

    # 4. Get color map from .uns (assumes this is already set, like in your original code)
    if not pd.api.types.is_categorical_dtype(XeniumData.obs[annotation_key]):
        # make sure it's categorical so .cat.categories works
        XeniumData.obs[annotation_key] = XeniumData.obs[annotation_key].astype('category')

    cluster_colors = dict(
        zip(
            XeniumData.obs[annotation_key].cat.categories,
            XeniumData.uns[f'{annotation_key}_colors']
        )
    )

    # Map colors for the subset
    cell_subset.obs['color'] = cell_subset.obs[annotation_key].map(cluster_colors)

    # 5. Plot populations (layering in the order provided)
    for pop in cell_populations:
        sub = cell_subset[cell_subset.obs[annotation_key] == pop]
        if sub.n_obs == 0:
            continue

        ax.scatter(
            sub.obsm['spatial'][:, 0],
            sub.obsm['spatial'][:, 1],
            c=sub.obs['color'],
            s=90,
            alpha=1.0 if pop != 'IEC_CT_colonocyte' else 0.8,  # mimic original layering
            label=pop
        )

    # 6. Axis formatting
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel('spatial1')
    ax.set_ylabel('spatial2')
    ax.set_aspect('equal')

    # 7. Legend only for the populations actually used
    legend_elements = [
        plt.Line2D(
            [0], [0],
            marker='o',
            color='w',
            markerfacecolor=cluster_colors[pop],
            markersize=9,
            label=pop
        )
        for pop in cell_populations
        if pop in cluster_colors
    ]
    ax.legend(
        handles=legend_elements,
        loc='upper center',
        bbox_to_anchor=(0.5, -0.05),
        fontsize=10
    )

    plt.tight_layout()

    # 8. Optional save
    if save_path is not None:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')

    plt.show()

# %%
plot_spatial_scatter_with_overlay(XeniumData, 
                                  cell_populations = ['IEC_CT_colonocyte', 'Fibroblast_IAF', 'MNP_monocyte'], 
                                  core_id = "HS37_HC_5")

# %%
plot_spatial_scatter_with_overlay(XeniumData, 
                                  cell_populations = ['IEC_CT_colonocyte', 'Fibroblast_IAF', 'MNP_monocyte'], 
                                  core_id = "HS34_VDZ_C_PRE_1_Mayo2_responder")

# %%
plot_spatial_scatter_with_overlay(XeniumData, 
                                  cell_populations = ['IEC_CT_colonocyte', 'Fibroblast_IAF', 'MNP_monocyte'], 
                                  core_id = "HS50_VDZ_RS_PRE_1_Mayo2_non-responder")

# %% [markdown]
# ## Fibroblast subsets + more

# %%
def plot_spatial_scatter_with_overlay(
    XeniumData,
    cell_populations,
    core_id,
    save_path=None,
    fig_width=5,
    fig_height=6
):
    # Define custom colors for each cell population
    custom_colors = {
        'B': 'gold',
        'Fibroblast_submucosal_S3': 'forestgreen',
        'Fibroblast_FRC_S4': 'lime',
        'IEC_CT_colonocyte': 'crimson',
        'IEC_ISC': 'lightpink',
        'Fibroblast_CTF_S2': 'blue',
        'Fibroblast_cCF_S1': 'deepskyblue',
    }

    annot_col = '24_05_29_Fine_annotations_Xenium_combined'
    core_col = 'Patient_ID_cores_combined'

    # Filter cells by core
    core_mask = XeniumData.obs[core_col] == core_id
    specified_core = XeniumData[core_mask, :].copy()

    # Extract subset of data for specified cell populations
    pop_mask = specified_core.obs[annot_col].isin(cell_populations).values
    cell_subset = specified_core[pop_mask, :].copy()

    # Create a figure
    fig, ax = plt.subplots(figsize=(fig_width, fig_height))

    # Map custom colors onto subset
    cell_subset.obs['color'] = cell_subset.obs[annot_col].map(custom_colors)

    # ---- Plot each population in order ----

    # B cells
    B_subset = cell_subset[cell_subset.obs[annot_col] == 'B']
    ax.scatter(
        B_subset.obsm['spatial'][:, 0],
        B_subset.obsm['spatial'][:, 1],
        c=B_subset.obs['color'],
        s=55,
        alpha=0.7,
        label='B'
    )

    # Fibroblast_submucosal_S3
    Fibroblast_submucosal_S3_subset = cell_subset[cell_subset.obs[annot_col] == 'Fibroblast_submucosal_S3']
    ax.scatter(
        Fibroblast_submucosal_S3_subset.obsm['spatial'][:, 0],
        Fibroblast_submucosal_S3_subset.obsm['spatial'][:, 1],
        c=Fibroblast_submucosal_S3_subset.obs['color'],
        s=55,
        alpha=0.7,
        label='Fibroblast_submucosal_S3'
    )

    # Fibroblast_FRC_S4
    Fibroblast_FRC_S4_subset = cell_subset[cell_subset.obs[annot_col] == 'Fibroblast_FRC_S4']
    ax.scatter(
        Fibroblast_FRC_S4_subset.obsm['spatial'][:, 0],
        Fibroblast_FRC_S4_subset.obsm['spatial'][:, 1],
        c=Fibroblast_FRC_S4_subset.obs['color'],
        s=55,
        alpha=0.7,
        label='Fibroblast_FRC_S4'
    )

    # IEC_CT_colonocyte
    IEC_CT_colonocyte_subset = cell_subset[cell_subset.obs[annot_col] == 'IEC_CT_colonocyte']
    ax.scatter(
        IEC_CT_colonocyte_subset.obsm['spatial'][:, 0],
        IEC_CT_colonocyte_subset.obsm['spatial'][:, 1],
        c=IEC_CT_colonocyte_subset.obs['color'],
        s=55,
        alpha=0.7,
        label='IEC_CT_colonocyte'
    )

    # IEC_ISC
    IEC_ISC_subset = cell_subset[cell_subset.obs[annot_col] == 'IEC_ISC']
    ax.scatter(
        IEC_ISC_subset.obsm['spatial'][:, 0],
        IEC_ISC_subset.obsm['spatial'][:, 1],
        c=IEC_ISC_subset.obs['color'],
        s=55,
        alpha=0.7,
        label='IEC_ISC'
    )

    # Fibroblast_CTF_S2
    Fibroblast_CTF_S2_subset = cell_subset[cell_subset.obs[annot_col] == 'Fibroblast_CTF_S2']
    ax.scatter(
        Fibroblast_CTF_S2_subset.obsm['spatial'][:, 0],
        Fibroblast_CTF_S2_subset.obsm['spatial'][:, 1],
        c=Fibroblast_CTF_S2_subset.obs['color'],
        s=55,
        alpha=0.7,
        label='Fibroblast_CTF_S2'
    )

    # Fibroblast_cCF_S1
    Fibroblast_cCF_S1_subset = cell_subset[cell_subset.obs[annot_col] == 'Fibroblast_cCF_S1']
    ax.scatter(
        Fibroblast_cCF_S1_subset.obsm['spatial'][:, 0],
        Fibroblast_cCF_S1_subset.obsm['spatial'][:, 1],
        c=Fibroblast_cCF_S1_subset.obs['color'],
        s=55,
        alpha=0.7,
        label='Fibroblast_cCF_S1'
    )

    # Formatting
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel('spatial1')
    ax.set_ylabel('spatial2')
    ax.set_aspect('equal')

    # Legend from custom colors, only for cell_populations
    legend_elements = [
        plt.Line2D(
            [0], [0],
            marker='o',
            color='w',
            markerfacecolor=color,
            markersize=9,
            label=cell_type
        )
        for cell_type, color in custom_colors.items()
        if cell_type in cell_populations
    ]
    ax.legend(
        handles=legend_elements,
        loc='upper center',
        bbox_to_anchor=(0.5, -0.05),
        fontsize=10
    )

    plt.tight_layout()

    if save_path is not None:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')

    plt.show()

# %% [markdown]
# HC plots

# %%
plot_spatial_scatter_with_overlay(XeniumData, 
                                  cell_populations = ['IEC_CT_colonocyte', 'IEC_ISC', 'Fibroblast_cCF_S1', 'Fibroblast_CTF_S2', 'Fibroblast_submucosal_S3', 'Fibroblast_FRC_S4', 'B'], 
                                  core_id = "HS39_HC_1")

# %%
plot_spatial_scatter_with_overlay(XeniumData, 
                                  cell_populations = ['IEC_CT_colonocyte', 'IEC_ISC', 'Fibroblast_cCF_S1', 'Fibroblast_CTF_S2', 'Fibroblast_submucosal_S3', 'Fibroblast_FRC_S4', 'B'], 
                                  core_id = "HS42_HC_1")

# %% [markdown]
# UC plots

# %%
plot_spatial_scatter_with_overlay(XeniumData, 
                                  cell_populations = ['IEC_CT_colonocyte', 'IEC_ISC', 'Fibroblast_cCF_S1', 'Fibroblast_CTF_S2', 'Fibroblast_submucosal_S3', 'Fibroblast_FRC_S4', 'B'], 
                                  core_id = "HS44_VDZ_C_PRE_1_Mayo0_responder")

# %%
plot_spatial_scatter_with_overlay(XeniumData, 
                                  cell_populations = ['IEC_CT_colonocyte', 'IEC_ISC', 'Fibroblast_cCF_S1', 'Fibroblast_CTF_S2', 'Fibroblast_submucosal_S3', 'Fibroblast_FRC_S4', 'B'], 
                                  core_id = "HS32_VDZ_RC_POST_1_Mayo0_responder")

# %% [markdown]
# # Part 3: Plotting Cores with All Coarse or Fine Annotations
#
# Currently set up to use Xenium Dataset 1 slide 1

# %%
def plot_spatial_scatter_randomized(
    adata,
    core_id,
    annotation_col,
    core_col,
    save_path=None,          # Only saves if provided
    fig_width=5,
    fig_height=6,
    point_size=25,
    alpha=0.7,
    seed=0,                  # Set None for new random order each run
    show_legend=True,
):
    # -----------------------------
    # Subset to specified core
    # -----------------------------
    ad = adata[adata.obs[core_col] == core_id]

    if ad.n_obs == 0:
        raise ValueError(f"No cells found for core_id '{core_id}'")

    # -----------------------------
    # Build color map
    # -----------------------------
    color_key = f"{annotation_col}_colors"
    if color_key not in adata.uns:
        raise ValueError(f"No color key found in adata.uns['{color_key}']")

    if hasattr(adata.obs[annotation_col], "cat"):
        categories = list(adata.obs[annotation_col].cat.categories)
    else:
        categories = sorted(adata.obs[annotation_col].unique())

    colors = adata.uns[color_key]
    color_map = dict(zip(categories, colors))

    # -----------------------------
    # Extract coordinates + labels
    # -----------------------------
    coords = ad.obsm["spatial"]
    labels = ad.obs[annotation_col].astype(str).to_numpy()
    point_colors = np.array([color_map.get(l, "gray") for l in labels])

    # -----------------------------
    # Randomize plotting order
    # -----------------------------
    rng = np.random.default_rng(seed) if seed is not None else np.random.default_rng()
    perm = rng.permutation(coords.shape[0])

    coords = coords[perm]
    labels = labels[perm]
    point_colors = point_colors[perm]

    # -----------------------------
    # Plot
    # -----------------------------
    fig, ax = plt.subplots(figsize=(fig_width, fig_height))

    ax.scatter(
        coords[:, 0],
        coords[:, 1],
        c=point_colors,
        s=point_size,
        alpha=alpha,
        linewidths=0,
    )

    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel("spatial1")
    ax.set_ylabel("spatial2")
    ax.set_aspect("equal")

    # -----------------------------
    # Legend (optional)
    # -----------------------------
    if show_legend:
        present_types = sorted(set(labels), key=lambda x: categories.index(x) if x in categories else 1e9)

        legend_elements = [
            plt.Line2D(
                [0], [0],
                marker="o",
                color="w",
                markerfacecolor=color_map.get(ct, "gray"),
                markersize=7,
                label=ct
            )
            for ct in present_types
        ]

        ax.legend(
            handles=legend_elements,
            loc="upper center",
            bbox_to_anchor=(0.5, -0.05),
            fontsize=8,
            ncol=2,
            frameon=False
        )

    plt.tight_layout()

    # -----------------------------
    # Save only if requested
    # -----------------------------
    if save_path is not None:
        plt.savefig(save_path, bbox_inches="tight", dpi=300)
        print(f"Figure saved to: {save_path}")

    plt.show()

# %% [markdown]
# HS39_HC_1

# %%
plot_spatial_scatter_randomized(
    adata=XeniumData,
    core_col="Patient_ID_cores_combined",
    core_id="HS39_HC_1",
    seed=1,          # keep reproducible randomization
    show_legend=False,
    annotation_col="24_05_29_Fine_annotations_Xenium_combined",
    save_path=None
)

# %%
plot_spatial_scatter_randomized(
    adata=XeniumData,
    core_col="Patient_ID_cores_combined",
    core_id="HS39_HC_1",
    seed=1,          # keep reproducible randomization
    show_legend=False,
    annotation_col="25_06_11_Common_Coarse_Xenium_Combinedv3",
    save_path=None
)

# %% [markdown]
# HS44_VDZ_C_PRE_1_Mayo0_responder

# %%
plot_spatial_scatter_randomized(
    adata=XeniumData,
    core_col="Patient_ID_cores_combined",
    core_id="HS44_VDZ_C_PRE_1_Mayo0_responder",
    seed=1,          # keep reproducible randomization
    show_legend=False,
    annotation_col="24_05_29_Fine_annotations_Xenium_combined",
    save_path=None
)

# %%
plot_spatial_scatter_randomized(
    adata=XeniumData,
    core_col="Patient_ID_cores_combined",
    core_id="HS44_VDZ_C_PRE_1_Mayo0_responder",
    seed=1,          # keep reproducible randomization
    show_legend=False,
    annotation_col="25_06_11_Common_Coarse_Xenium_Combinedv3",
    save_path=None
)

# %% [markdown]
# HS50_VDZ_RS_PRE_1_Mayo2_non-responder

# %%
plot_spatial_scatter_randomized(
    adata=XeniumData,
    core_col="Patient_ID_cores_combined",
    core_id="HS50_VDZ_RS_PRE_1_Mayo2_non-responder",
    seed=1,          # keep reproducible randomization
    show_legend=False,
    annotation_col="24_05_29_Fine_annotations_Xenium_combined",
    save_path=None
)

# %%
plot_spatial_scatter_randomized(
    adata=XeniumData,
    core_col="Patient_ID_cores_combined",
    core_id="HS50_VDZ_RS_PRE_1_Mayo2_non-responder",
    seed=1,          # keep reproducible randomization
    show_legend=False,
    annotation_col="25_06_11_Common_Coarse_Xenium_Combinedv3",
    save_path=None
)

# %% [markdown]
# # Part 4: Gene signatures distinguishing UC PRE Responders and Non-responders
#
# Currently set up to use Xenium Dataset 1 Integrated (slides 1 and 2)

# %% [markdown]
# ## Calculate mean expression of gene signature lists on the log normalized counts
#
# For each gene set:
# * Take one cell (a row of your AnnData).
# * Pull out the expression values for just the genes in that set (from the log_normalized_counts layer).
# * Average those values → that gives you a single number summarizing that cell’s mean expression across the set.
# * Repeat for every cell → you get a new metadata column in .obs (e.g. MeanExp_R_IEC).
# So each column in .obs now holds the per-cell average expression for one of your gene sets.

# %%
### Calculate mean expression of gene signature lists per cell on the log normalized counts

adata = Int_XeniumData  # shorthand (and note that we're using the Integrated data object here)
layer_to_use = "log_normalized_counts"

def get_matrix(A, genes, layer=None):
    sub = A[:, genes]
    return sub.layers[layer] if layer is not None else sub.X

def row_means(M):
    if hasattr(M, "tocsc"):  # sparse
        return np.asarray(M.mean(axis=1)).ravel()
    return M.mean(axis=1)

# ---- Define gene sets ----
# IMPORTANT:
# - Fill in gene names manually (one per line, no commas or quotes)
# - Gene signature lists are available in our manuscript
# - We will update this notebook with full gene lists once the manuscript is public
#
# Example format (replace with real genes):
# GENE1
# GENE2
# GENE3

R_IEC = [g.strip() for g in """
GENE1
GENE2
GENE3
""".splitlines() if g.strip()]

NR_IAF = [g.strip() for g in """
GENE1
GENE2
GENE3
""".splitlines() if g.strip()]

NR_GALT = [g.strip() for g in """
GENE1
GENE2
GENE3
""".splitlines() if g.strip()]

LeadingEdge_R = [g.strip() for g in """
GENE1
GENE2
GENE3
""".splitlines() if g.strip()]

LeadingEdge_NR = [g.strip() for g in """
GENE1
GENE2
GENE3
""".splitlines() if g.strip()]

gene_sets = {
    "MeanExp_R_IEC": R_IEC,
    "MeanExp_NR_IAF": NR_IAF,
    "MeanExp_NR_GALT": NR_GALT,
    "MeanExp_R_LeadingEdge": LeadingEdge_R,
    "MeanExp_NR_LeadingEdge": LeadingEdge_NR,
}

geneset_cols = list(gene_sets.keys())

# ---- Compute per-cell mean expression for each set ----
varnames = set(adata.var_names.astype(str))

for col_name, genes in gene_sets.items():
    present = [g for g in genes if g in varnames]
    missing = [g for g in genes if g not in varnames]

    if len(present) == 0:
        adata.obs[col_name] = np.nan
        print(f"[{col_name}] 0/{len(genes)} genes found in adata.var_names. Column filled with NaN.")
        continue

    M = get_matrix(adata, present, layer=layer_to_use)
    adata.obs[col_name] = row_means(M)

    print(
        f"[{col_name}] Using {len(present)}/{len(genes)} genes. "
        f"Missing: {', '.join(missing) if missing else 'none'}"
    )

adata.obs[geneset_cols].head()

# %%
adata.obs['24_01_17_Condition'].unique()

# %%
## If desired, users can export this file to compare values with CellCharter neighborhood assignments (see CellCharter notebook)

#adata.obs[
#    ["cell_id", "MeanExp_R_IEC", "MeanExp_NR_IAF", "MeanExp_NR_GALT"]
#].to_csv("/path/Xenium_GeneSignatureExpression.csv", index=False)

# %% [markdown]
# ## Gene signature expression box and whiskers plot

# %%
### Group by HS

group_col = "24_01_17_HS"
condition_col = "24_01_17_Condition"
subset_order = ["HC", "UCPRE_R", "UCPRE_NR"]

condition_map = {
    "HC": "HC",
    "PRE_VDZ_R": "UCPRE_R",
    "PRE_VDZ_NR": "UCPRE_NR",
}

# Keep only the conditions of interest
adata_sub = adata[adata.obs[condition_col].isin(condition_map.keys())].copy()

def HS_means_df(A, condition_value, subset_name):
    df = (
        A.obs.loc[A.obs[condition_col] == condition_value, [group_col] + geneset_cols]
        .dropna(subset=[group_col])
        .copy()
    )

    # Convert HS labels to string so unused categorical levels do not carry through
    df[group_col] = df[group_col].astype(str)

    HS_mean = (
        df.groupby(group_col, as_index=False, observed=True)[geneset_cols]
        .mean(numeric_only=True)
    )
    HS_mean["Subset"] = subset_name
    return HS_mean

HS_means_wide = pd.concat(
    [HS_means_df(adata_sub, cond, subset) for cond, subset in condition_map.items()],
    ignore_index=True
)

HS_means_wide["Subset"] = pd.Categorical(
    HS_means_wide["Subset"],
    categories=subset_order,
    ordered=True
)

HS_means_wide = HS_means_wide.sort_values(["Subset", group_col]).reset_index(drop=True)

display(HS_means_wide)

# Save HS_means_wide if desired
#HS_means_wide.to_csv("/path/Xenium_HS_means_wide.csv", index=False)

# %%
### Prepare HS-level long-format data for plotting

geneset_cols_plot = ["MeanExp_R_IEC", "MeanExp_NR_IAF", "MeanExp_NR_GALT"]
geneset_order = geneset_cols_plot

# Optional: subset by slide or other metadata
# HS_means_wide_sub = HS_means_wide.query("slide == 'HS58'")
HS_means_wide_sub = HS_means_wide.copy()

df_long = HS_means_wide_sub.melt(
    id_vars=[group_col, "Subset"],
    value_vars=geneset_cols_plot,
    var_name="GeneSet",
    value_name="MeanExpression"
).dropna(subset=["MeanExpression"])

df_long["Subset"] = pd.Categorical(df_long["Subset"], subset_order, ordered=True)
df_long["GeneSet"] = pd.Categorical(df_long["GeneSet"], geneset_order, ordered=True)

# %%
### Kruskal–Wallis statistics

stats_results = []

for gs in geneset_order:
    sub_df = df_long[df_long["GeneSet"] == gs]

    groups = [
        sub_df.loc[sub_df["Subset"] == s, "MeanExpression"].dropna()
        for s in subset_order
    ]

    stat, pval = kruskal(*groups)

    stats_results.append({
        "GeneSet": gs,
        "Test": "Kruskal–Wallis",
        "Statistic": stat,
        "p_value": pval
    })

stats_df = pd.DataFrame(stats_results)
display(stats_df)

# %%
### Pairwise Mann–Whitney tests + FDR correction

pairwise_results = []

for gs in geneset_order:
    sub_df = df_long[df_long["GeneSet"] == gs]

    for a, b in combinations(subset_order, 2):
        x = sub_df.loc[sub_df["Subset"] == a, "MeanExpression"].dropna()
        y = sub_df.loc[sub_df["Subset"] == b, "MeanExpression"].dropna()

        stat, pval = mannwhitneyu(x, y, alternative="two-sided")

        pairwise_results.append({
            "GeneSet": gs,
            "Comparison": f"{a} vs {b}",
            "Test": "Mann–Whitney U",
            "Statistic": stat,
            "p_value": pval
        })

pairwise_df = pd.DataFrame(pairwise_results)

pairwise_df["p_adj"] = multipletests(
    pairwise_df["p_value"],
    method="fdr_bh"
)[1]

def p_to_stars(p):
    if pd.isna(p):
        return None
    if p < 0.0001:
        return "****"
    if p < 0.001:
        return "***"
    if p < 0.01:
        return "**"
    if p < 0.05:
        return "*"
    return None

pairwise_df["stars"] = pairwise_df["p_adj"].apply(p_to_stars)
pairwise_df = pairwise_df.sort_values(["GeneSet", "p_adj"])

display(pairwise_df)

# %%
### Helper for significance brackets

def add_sig_bracket(ax, x1, x2, y, text, h, lw=1.4):
    ax.plot(
        [x1, x1, x2, x2],
        [y, y + h, y + h, y],
        lw=lw,
        c="black",
        clip_on=False
    )
    ax.text(
        (x1 + x2) / 2,
        y + h,
        text,
        ha="center",
        va="bottom",
        fontsize=13,
        fontweight="bold"
    )

# %%
### HS-level mean expression box and whiskers plot with pairwise FDR brackets

sns.set(style="ticks", rc={"figure.figsize": (8.5, 6)})

palette = {
    "HC": "lightgray",
    "UCPRE_R": "cornflowerblue",
    "UCPRE_NR": "darkorange"
}

fig, ax = plt.subplots()

sns.boxplot(
    data=df_long,
    x="GeneSet",
    y="MeanExpression",
    hue="Subset",
    order=geneset_order,
    hue_order=subset_order,
    palette=palette,
    width=0.72,
    fliersize=0,
    ax=ax
)

strip_palette = {s: "black" for s in subset_order}

sns.stripplot(
    data=df_long,
    x="GeneSet",
    y="MeanExpression",
    hue="Subset",
    order=geneset_order,
    hue_order=subset_order,
    dodge=True,
    jitter=0.18,
    size=4.5,
    alpha=0.6,
    palette=strip_palette,
    edgecolor="black",
    linewidth=0.25,
    ax=ax
)

# Fix duplicate legend
handles, labels = ax.get_legend_handles_labels()
ax.legend(
    handles[:len(subset_order)],
    labels[:len(subset_order)],
    title="",
    frameon=False,
    loc="best"
)

ax.set_xlabel("")
ax.set_ylabel("HS mean expression (log_normalized_counts)")
ax.tick_params(axis="x", labelsize=12)
ax.tick_params(axis="y", labelsize=11)

sns.despine(offset=5, trim=False, ax=ax)

custom_ticklabels = [
    "IEC_R",
    "IAF-Monocyte\nNeutrophil_NR",
    "GALT-B-DC\nS4_fibroblast_NR"
]
ax.set_xticklabels(custom_ticklabels)

# -------------------------
# Bracket annotations
# -------------------------
offsets = np.linspace(-0.24, 0.24, len(subset_order))

x_lookup = {}
for i, gs in enumerate(geneset_order):
    for j, subset in enumerate(subset_order):
        x_lookup[(gs, subset)] = i + offsets[j]

ymin = df_long["MeanExpression"].min()
ymax = df_long["MeanExpression"].max()
yrng = ymax - ymin if ymax > ymin else 1.0

base_pad = 0.08 * yrng
step = 0.08 * yrng
h = 0.02 * yrng

for gs in geneset_order:
    gs_max = df_long.loc[df_long["GeneSet"] == gs, "MeanExpression"].max()
    y = gs_max + base_pad

    gs_stats = pairwise_df[
        (pairwise_df["GeneSet"] == gs) &
        (pairwise_df["stars"].notna())
    ].sort_values("p_adj")

    for _, r in gs_stats.iterrows():
        a, b = r["Comparison"].split(" vs ")
        x1 = x_lookup[(gs, a)]
        x2 = x_lookup[(gs, b)]
        add_sig_bracket(ax, x1, x2, y, r["stars"], h=h)
        y += step

bottom_pad = 0.02 * yrng
ax.set_ylim(-bottom_pad, ymax + base_pad + step * 3)

plt.tight_layout()
# plt.savefig(f"{base_path}/Dataset1Xenium_GeneSignatureMeanExpressionPerHS.pdf", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Gene signature expression spatial scatter plots

# %%
### Spatial scatter plot function setup

adata.obs_names = adata.obs_names.astype(str)

display(adata.obs["Patient_ID_cores_combined"].unique())

def plot_spatial_core_scalar(
    A,
    obs_key,
    core_id,
    save_plot=False,
    fig_width=5,
    fig_height=5,
    point_size=2000,
    cmap="viridis",
    robust=True,
    vmin=None,
    vmax=None,
    flip_y=False,
    save_path="/path/Cores_NoPlotTitle/",
):
    """
    Plot a spatial scatter for a single core colored by a scalar obs column.
    """

    # --- Basic checks ---
    if "Patient_ID_cores_combined" not in A.obs.columns:
        raise KeyError("Missing 'Patient_ID_cores_combined' in .obs")
    if obs_key not in A.obs.columns:
        raise KeyError(f"Missing '{obs_key}' in .obs")
    if "spatial" not in A.obsm:
        raise KeyError("Missing 'spatial' in .obsm")

    # --- Subset to the requested core ---
    core_view = A[A.obs["Patient_ID_cores_combined"].astype(str) == str(core_id)].copy()
    if core_view.n_obs == 0:
        raise ValueError(f"No cells found for core_id '{core_id}'.")

    coords = core_view.obsm["spatial"]
    if coords.shape[0] != core_view.n_obs or coords.shape[1] < 2:
        raise ValueError("Invalid 'spatial' coordinates in .obsm['spatial'].")

    values = core_view.obs[obs_key].astype(float).to_numpy()

    # --- Color scale ---
    if vmin is not None and vmax is not None:
        vmin, vmax = float(vmin), float(vmax)
    else:
        if robust:
            vmin, vmax = np.nanpercentile(values, [1, 99])
        else:
            vmin, vmax = np.nanmin(values), np.nanmax(values)

    # --- Plot ---
    fig, ax = plt.subplots(figsize=(fig_width, fig_height), dpi=300)
    sc = ax.scatter(
        coords[:, 0],
        coords[:, 1],
        c=values,
        s=point_size,
        cmap=cmap,
        vmin=vmin,
        vmax=vmax,
        edgecolor="none",
        alpha=0.9,
    )

    cbar = plt.colorbar(sc, ax=ax, fraction=0.046, pad=0.04)
    cbar.set_label(obs_key, rotation=270, labelpad=20, fontsize=14)
    cbar.ax.tick_params(labelsize=12)

    ax.set_xlabel("spatial1")
    ax.set_ylabel("spatial2")
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_aspect("equal", adjustable="box")

    if flip_y:
        ax.invert_yaxis()

    plt.tight_layout()

    # --- Save if requested ---
    if save_plot:
        os.makedirs(save_path, exist_ok=True)
        file_name = f"SpatialScatterPlot_core{core_id}_{obs_key}_NoPlotTitle.pdf"
        full_path = os.path.join(save_path, file_name)
        plt.savefig(full_path, format="pdf", bbox_inches="tight", dpi=300)
        print(f"Saved: {full_path}")

    plt.show()

# %% [markdown]
# HS46_VDZ_LC_PRE_1_Mayo3_non-responder

# %%
# Plot MeanExp_NR_GALT on one UCPRE_NR core
plot_spatial_core_scalar(
    adata,
    obs_key='MeanExp_NR_GALT',
    core_id='HS46_VDZ_LC_PRE_1_Mayo3_non-responder',
   # save_plot=True,      
    point_size=4,
    cmap='viridis',
    robust=True,
    vmin= 0,
    vmax=0.7,
)



# Options: 'MeanExp_R_IEC', 'MeanExp_NR_IAF', 'MeanExp_NR_GALT', 'MeanExp_R_LeadingEdge', 'MeanExp_NR_LeadingEdge'

# %%
# Plot MeanExp_NR_IAF on one UCPRE_NR core
plot_spatial_core_scalar(
    adata,
    obs_key='MeanExp_NR_IAF',
    core_id='HS46_VDZ_LC_PRE_1_Mayo3_non-responder',
   # save_plot=True,      
    point_size=4,
    cmap='viridis',
    robust=True,
    vmin= 0,
    vmax=0.7,
)



# Options: 'MeanExp_R_IEC', 'MeanExp_NR_IAF', 'MeanExp_NR_GALT', 'MeanExp_R_LeadingEdge', 'MeanExp_NR_LeadingEdge'

# %%
# Plot MeanExp_R_IEC on one UCPRE_NR core
plot_spatial_core_scalar(
    adata,
    obs_key='MeanExp_R_IEC',
    core_id='HS46_VDZ_LC_PRE_1_Mayo3_non-responder',
  #  save_plot=True,      
    point_size=4,
    cmap='viridis',
    robust=True,
    vmin= 0,
    vmax=0.7,
)



# Options: 'MeanExp_R_IEC', 'MeanExp_NR_IAF', 'MeanExp_NR_GALT', 'MeanExp_R_LeadingEdge', 'MeanExp_NR_LeadingEdge'

# %% [markdown]
# HS50_VDZ_RS_PRE_1_Mayo2_non-responder

# %%
# Plot MeanExp_NR_GALT on one UCPRE_NR core
plot_spatial_core_scalar(
    adata,
    obs_key='MeanExp_NR_GALT',
    core_id='HS50_VDZ_RS_PRE_1_Mayo2_non-responder',
   # save_plot=True,      
    point_size=4,
    cmap='viridis',
    robust=True,
    vmin= 0,
    vmax=0.7,
)



# Options: 'MeanExp_R_IEC', 'MeanExp_NR_IAF', 'MeanExp_NR_GALT', 'MeanExp_R_LeadingEdge', 'MeanExp_NR_LeadingEdge'

# %%
# Plot MeanExp_NR_IAF on one UCPRE_NR core
plot_spatial_core_scalar(
    adata,
    obs_key='MeanExp_NR_IAF',
    core_id='HS50_VDZ_RS_PRE_1_Mayo2_non-responder',
  #  save_plot=True,      
    point_size=4,
    cmap='viridis',
    robust=True,
    vmin= 0,
    vmax=0.7,
)



# Options: 'MeanExp_R_IEC', 'MeanExp_NR_IAF', 'MeanExp_NR_GALT', 'MeanExp_R_LeadingEdge', 'MeanExp_NR_LeadingEdge'

# %%
# Plot MeanExp_R_IEC on one UCPRE_NR core
plot_spatial_core_scalar(
    adata,
    obs_key='MeanExp_R_IEC',
    core_id='HS50_VDZ_RS_PRE_1_Mayo2_non-responder',
  #  save_plot=True,      
    point_size=4,
    cmap='viridis',
    robust=True,
    vmin= 0,
    vmax=0.7,
)



# Options: 'MeanExp_R_IEC', 'MeanExp_NR_IAF', 'MeanExp_NR_GALT', 'MeanExp_R_LeadingEdge', 'MeanExp_NR_LeadingEdge'

# %% [markdown]
# HS34_VDZ_C_PRE_1_Mayo2_responder

# %%
# Plot MeanExp_NR_GALT on one UCPRE_R core
plot_spatial_core_scalar(
    adata,
    obs_key='MeanExp_NR_GALT',
    core_id='HS34_VDZ_C_PRE_1_Mayo2_responder',
  #  save_plot=True,      
    point_size=4,
    cmap='viridis',
    robust=True,
    vmin= 0,
    vmax=0.7,
)



# Options: 'MeanExp_R_IEC', 'MeanExp_NR_IAF', 'MeanExp_NR_GALT', 'MeanExp_R_LeadingEdge', 'MeanExp_NR_LeadingEdge'

# %%
# Plot MeanExp_NR_IAF on one UCPRE_R core
plot_spatial_core_scalar(
    adata,
    obs_key='MeanExp_NR_IAF',
    core_id='HS34_VDZ_C_PRE_1_Mayo2_responder',
  #  save_plot=True,      
    point_size=4,
    cmap='viridis',
    robust=True,
    vmin= 0,
    vmax=0.7,
)



# Options: 'MeanExp_R_IEC', 'MeanExp_NR_IAF', 'MeanExp_NR_GALT', 'MeanExp_R_LeadingEdge', 'MeanExp_NR_LeadingEdge'

# %%
# Plot MeanExp_R_IEC on one UCPRE_R core
plot_spatial_core_scalar(
    adata,
    obs_key='MeanExp_R_IEC',
    core_id='HS34_VDZ_C_PRE_1_Mayo2_responder',
  #  save_plot=True,      
    point_size=4,
    cmap='viridis',
    robust=True,
    vmin= 0,
    vmax=0.7,
)



# Options: 'MeanExp_R_IEC', 'MeanExp_NR_IAF', 'MeanExp_NR_GALT', 'MeanExp_R_LeadingEdge', 'MeanExp_NR_LeadingEdge'
